# %%
import requests
def slider(text):
#     text = input('Enter')
    s_url = "https://imdb-api.com/en/API/SearchTitle/k_5wie7okz/{}".format(text)
    s_data = requests.get(s_url)
    s_data = s_data.json()
    img = s_data['results']
    dimp = img[0]
    lim = dimp['image']
    return lim

# %%
def fetch_poster(movie_id):
    url = "https://api.themoviedb.org/3/movie/{}?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US".format(movie_id)
    data = requests.get(url)
    data = data.json()
    poster_path = data['poster_path']
    full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
    return full_path

# %%
def pop_mov_poster(ind):
    s_url = "https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"
    s_data = requests.get(s_url)
    s_data = s_data.json()
    pop_mov = s_data['results']
    mov = list(pop_mov)
    pop_path = 'poster_path'
    full_path = "https://image.tmdb.org/t/p/w500/"
    lvalues = [item[pop_path] for item in pop_mov]
    final_poster = full_path + lvalues[ind]
    return final_poster
pop_mov_poster(2)
# Out:
# 'https://image.tmdb.org/t/p/w500//1BIoJGKbXjdFDAqUEiA2VHqkK1Z.jpg'

# %%
import requests
def pop_mov_poster(ind):
    s_url = "https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"
    s_data = requests.get(s_url)
    s_data = s_data.json()
    pop_mov = s_data['results']
    lst = list(pop_mov)
    pop_path = 'poster_path'
    full_path = "https://image.tmdb.org/t/p/w500/"
    lvalues = [item[pop_path] for item in pop_mov]
    print(full_path + lvalues[ind])

pop_mov_poster(5)
# Out:
# https://image.tmdb.org/t/p/w500//kfQJQWFEoWRVBH8FUKnT0HX1yRS.jpg

# %%
# Out:
# https://image.tmdb.org/t/p/w500//rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg

# %%
slider('encanto')
# Out:
# 'https://imdb-api.com/images/original/MV5BNjE5NzA4ZDctOTJkZi00NzM0LTkwOTYtMDI4MmNkMzIxODhkXkEyXkFqcGdeQXVyNjY1MTg4Mzc@._V1_Ratio0.7273_AL_.jpg'

# %%
def recommend(movie):
    index = movies[movies['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_movie_names = []
    recommended_movie_posters = []
    for i in distances[1:6]:
        # fetch the movie poster
        movie_id = movies.iloc[i[0]].movie_id
        recommended_movie_posters.append(fetch_poster(movie_id))
        recommended_movie_names.append(movies.iloc[i[0]].title)

    return recommended_movie_names,recommended_movie_posters

# %%
    s_url = "https://imdb-api.com/en/API/MostPopularMovies/k_5wie7okz"
    s_data = requests.get(s_url)
    s_data = s_data.json()
    itm = s_data['items']
    name = []
    post = []
    nb = append(itm[1:3]
    print(nb)
# Out:
#   File "<ipython-input-12-7a4e8ad35f02>", line 8
#     print(nb)
#     ^
# SyntaxError: invalid syntax

# %%
#https://imdb-api.com/en/API/MostPopularMovies/k_5wie7okz
def top():
    s_url = "https://imdb-api.com/en/API/MostPopularMovies/k_5wie7okz"
    s_data = requests.get(s_url)
    s_data = s_data.json()
    itm = s_data['items']
    dimp = itm[6]
    lim = dimp['year']
    for i in itm:
         print(lim)
    return 

top()
# Out:
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021
# 2021

# %%
#https://imdb-api.com/en/API/MostPopularMovies/k_5wie7okz

s_url = "https://imdb-api.com/en/API/MostPopularMovies/k_5wie7okz"
s_data = requests.get(s_url)
s_data = s_data.json()
# itm = s_data['items']
# dimp = itm[6]
# lim = dimp['year']
s_data
# Out:
# {'items': [{'id': 'tt11214590',
#    'rank': '1',
#    'rankUpDown': '+1',
#    'title': 'House of Gucci',
#    'fullTitle': 'House of Gucci (2021)',
#    'year': '2021',
#    'image': 'https://m.media-amazon.com/images/M/MV5BYzdlMTMyZWQtZWNmMC00MTJiLWIyMWMtM2ZlZDdlYzZhNTc0XkEyXkFqcGdeQXVyMTMzNDE5NDM2._V1_UX128_CR0,3,128,176_AL_.jpg',
#    'crew': 'Ridley Scott (dir.), Lady Gaga, Adam Driver',
#    'imDbRating': '7.0',
#    'imDbRatingCount': '25486'},
#   {'id': 'tt10293406',
#    'rank': '2',
#    'rankUpDown': '+34',
#    'title': 'The Power of the Dog',
#    'fullTitle': 'The Power of the Dog (2021)',
#    'year': '2021',
#    'image': 'https://m.media-amazon.com/images/M/MV5BZGRhYjE2NWUtN2FkNy00NGI3LTkxYWMtMDk4Yjg5ZjI3MWI2XkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_UX128_CR0,3,128,176_AL_.jpg',
#    'crew': 'Jane Campion (dir.), Benedict Cumberbatch, Kirsten Dunst',
#    'imDbRating': '7.0',
#    'imDbRatingCount': '22993'},
#   {'id': 'tt10872600',
#    'rank': '3',
# ...

# %%
def upcoming(x):
    s_url = "https://api.themoviedb.org/3/movie/upcoming?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"
    s_data = requests.get(s_url)
    s_data = s_data.json()
    dim = s_data['results']
    lim = list(dim)
    fin = []
    for i in dim[1:6]:
        x = "https://image.tmdb.org/t/p/w500/" +i['poster_path']
        fin.append(x)
    return x

# %%
def uc():
    s_url = "https://api.themoviedb.org/3/movie/upcoming?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"
    s_data = requests.get(s_url)
    s_data = s_data.json()
    dim = s_data['results']
    lim = list(dim)
    fin = []
    for i in dim[1:5]:
        x = "https://image.tmdb.org/t/p/w500/" +i['poster_path']
        fin.append(x)
    return fin

# %%
uc()
# Out:
# ['https://image.tmdb.org/t/p/w500//ygPTrycbMSFDc5zUpy4K5ZZtQSC.jpg',
#  'https://image.tmdb.org/t/p/w500//feKU4spZTEVz6UC63EBVdGAcBN7.jpg',
#  'https://image.tmdb.org/t/p/w500//1g0dhYtq4irTY1GPXvft6k4YLjm.jpg',
#  'https://image.tmdb.org/t/p/w500//zjrJE0fpzPvX8saJXj8VNfcjBoU.jpg']

# %%
def fetch_poster():
    url = "https://api.themoviedb.org/3/movie/upcoming?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"
    data = requests.get(url)
    data = data.json()
    poster_path = data['results']
    path = poster
    full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
    return full_path
fetch_poster()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-a6cb6ed2240b> in <module>
#       6     full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
#       7     return full_path
# ----> 8 fetch_poster()
#
# <ipython-input-117-a6cb6ed2240b> in fetch_poster()
#       4     data = data.json()
#       5     poster_path = data['results']
# ----> 6     full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
#       7     return full_path
#       8 fetch_poster()
#
# TypeError: can only concatenate str (not "list") to str

# %%
fin[1]
# Out:
# 'https://image.tmdb.org/t/p/w500//feKU4spZTEVz6UC63EBVdGAcBN7.jpg'

# %%
def fetch_poster(movie_id):
    url = "https://api.themoviedb.org/3/movie/upcoming{}?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US".format(movie_id)
    data = requests.get(url)
    data = data.json()
    poster_path = data['poster_path']
    full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
    return full_path
fetch_poster(634649)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-033c1e5e4985> in <module>
#       6     full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
#       7     return full_path
# ----> 8 fetch_poster(634649)
#
# <ipython-input-16-033c1e5e4985> in fetch_poster(movie_id)
#       3     data = requests.get(url)
#       4     data = data.json()
# ----> 5     poster_path = data['poster_path']
#       6     full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
#       7     return full_path
#
# KeyError: 'poster_path'

# %%
# !pip uninstall kivy
